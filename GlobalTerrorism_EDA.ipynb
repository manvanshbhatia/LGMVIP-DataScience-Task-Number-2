# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('GT.csv', encoding='latin-1')
# Out:
# C:\Users\91766\AppData\Local\Temp\ipykernel_15836\400246342.py:1: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('GT.csv', encoding='latin-1')

# %%
#To get the shape of df
df.shape
# Out:
# (181691, 135)

# %%
#To get the column names
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
#To get all the column names 
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
#To view head of df
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
#To view tail of df
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
#To view data types
df.dtypes
# Out:
# eventid        int64
# iyear          int64
# imonth         int64
# iday           int64
# approxdate    object
#                ...
# INT_LOG        int64
# INT_IDEO       int64
# INT_MISC       int64
# INT_ANY        int64
# related       object
# Length: 135, dtype: object

# %% [markdown]
# ### Null/ Missing values

# %%
#To check for null values
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df['approxdate'].notnull().sum()
# Out:
# 9239

# %% [markdown]
# only 0.05% of the values in this column are not null

# %%
df['related'].notnull().sum()
# Out:
# 25038

# %%
#To drop columns with missing values
df1 = df.dropna(axis = 1)
df1.shape
# Out:
# (181691, 29)

# %% [markdown]
# ### Duplicated values

# %%
#To check for duplicated values
df.duplicated().sum()
# Out:
# 0

# %%
df.hist(figsize = (40,80))
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Skewness

# %%
#.skew() gives the value of skewness for each column
skewness = df.skew()
skewness
# Out:
# C:\Users\91766\AppData\Local\Temp\ipykernel_15836\2779667898.py:2: FutureWarning: The default value of numeric_only in DataFrame.skew is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   skewness = df.skew()
# eventid      -0.619155
# iyear        -0.619067
# imonth        0.006750
# iday          0.019065
# extended      4.370397
#                ...
# nreleased     9.863306
# INT_LOG       0.042633
# INT_IDEO      0.053384
# INT_MISC    -10.495092
# INT_ANY      -0.137264
# Length: 77, dtype: float64

# %%
#To get the skewed columns
skewed_columns = skewness[abs(skewness) > 0.5].index
skewed_columns
# Out:
# Index(['eventid', 'iyear', 'extended', 'country', 'latitude', 'longitude',
#        'specificity', 'vicinity', 'crit1', 'crit2', 'crit3', 'doubtterr',
#        'alternative', 'multiple', 'success', 'suicide', 'attacktype1',
#        'attacktype2', 'attacktype3', 'natlty1', 'natlty2', 'natlty3',
#        'guncertain1', 'guncertain2', 'guncertain3', 'individual', 'nperps',
#        'nperpcap', 'claimed', 'claimmode', 'claim2', 'claimmode2',
#        'claimmode3', 'compclaim', 'weaptype1', 'weaptype2', 'weaptype3',
#        'weaptype4', 'weapsubtype4', 'nkill', 'nkillus', 'nkillter', 'nwound',
#        'nwoundus', 'nwoundte', 'property', 'propextent', 'propvalue',
#        'ishostkid', 'nhostkid', 'nhostkidus', 'nhours', 'ndays', 'ransom',
#        'ransomamt', 'ransomamtus', 'ransompaid', 'ransompaidus', 'nreleased',
#        'INT_MISC'],
#       dtype='object')

# %%
#To get non-skewed columns
normal_columns = skewness[abs(skewness) < 0.5].index
normal_columns
# Out:
# Index(['imonth', 'iday', 'region', 'targtype1', 'targsubtype1', 'targtype2',
#        'targsubtype2', 'targtype3', 'targsubtype3', 'claim3', 'weapsubtype1',
#        'weapsubtype2', 'weapsubtype3', 'hostkidoutcome', 'INT_LOG', 'INT_IDEO',
#        'INT_ANY'],
#       dtype='object')

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
sns.countplot(x=df['weaptype1'], data = df)
# Out:
# <Axes: xlabel='weaptype1', ylabel='count'>

# %%
df['region'].head()
# Out:
# 0    2
# 1    1
# 2    5
# 3    8
# 4    4
# Name: region, dtype: int64

# %% [markdown]
# To analyse the number of attacks over region

# %%
sns.countplot(x=df['region_txt'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Region')
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.countplot(x=df['iyear'], hue='success', data=df)
plt.ylabel('Number of attacks')
plt.xticks(rotation=90)
plt.xlabel('Attack Year')
plt.title('TERROR INCREASE',size=25, fontweight="bold")
plt.show()

# %% [markdown]
# ### Outlier Analysis
